# %%
#Mexico 
mexico_world_cup_starting_xi_vs_south_africa = [
    ["Raul Rangel", "GK", "Guadalajara", 74],
    ["Israel Reyes", "RB", "Club America", 75],
    ["Cesar Montes", "CB", "Lokomotiv Moscow", 75],
    ["Johan Vasquez", "CB", "Genoa", 79],
    ["Jesus Gallardo", "LB", "Toluca", 75],
    ["Erik Lira", "CDM", "Cruz Azul", 76],
    ["Alvaro Fidalgo", "CM", "Real Betis", 77],
    ["Brian Gutierrez", "CM", "Guadalajara", 77],
    ["Julian Quinones", "LW", "Al-Qadsiah", 81],
    ["Roberto Alvarado", "RW", "Guadalajara", 78],
    ["Raul Jimenez", "ST", "Fulham", 78]
]
mexico_world_cup_bench_vs_south_africa = [
    ["Alexis Vega", "LW", "Toluca", 77,],
    ["Gilberto Mora", "CM", "Tijuana", 75,],
    ["Luis Chavez", "CM", "Dynamo Moscow", 75,],
    ["Edson Alvarez", "CDM", "West Ham", 76,],
    ["Armando Gonzalez", "ST", "Guadalajara", 74,],
]

# %%
#South Africa
south_africa_world_cup_starting_xi_vs_mexico = [
    ["Ronwen Williams", "GK", "Mamelodi Sundowns", 66,],
    ["Khuliso Mudau", "RB", "Mamelodi Sundowns", 64,],
    ["Ime Okon", "CB", "Hannover", 66,],
    ["Nkosinathi Sibisi", "CB", "Orlando Pirates", 66,],
    ["Mbekezeli Mbokazi", "CB", "Chicago Fire", 72,],
    ["Aubrey Modiba", "LB", "Mamelodi Sundowns", 64,],
    ["Teboho Mokoena", "CM", "Mamelodi Sundowns", 65,],
    ["Sphephelo Sithole", "CM", "Tondela", 66,],
    ["Jayden Adams", "CDM", "Mamelodi Sundowns", 64,],
    ["Iqraam Rayners", "ST", "Mamelodi Sundowns", 64,],
    ["Lyle Foster", "ST", "Burnley", 71,],    
]
south_africa_world_cup_bench_vs_mexico = [
    ["Thalente Mbatha", "CDM", "Orlando Pirates", 62,],
    ["Themba Zwane", "CAM", "Mamelodi Sundowns", 64,],
    [" Evidence Makgopa", "ST", "Mamelodi Sundowns", 62,],
    ["Oswin Appollis", "RW", "Mamelodi Sundowns", 64,],

# %%
class PlayerProfile:
    def __init__(self, name, nation, position, overall_rating):
        self.name = name
        self.nation = nation
        self.position = position.lower()
        self.overall_rating = overall_rating
        self.base_rating = 6 # Initial Value of 6, some might have this value as 5 depending on what you believe an I0 should be.
        self.match_rating = self.base_rating

    def adjust_rating(self, delta):
        self.match_rating = max(0, min(10, self.match_rating + delta))
#This is the importance of my system, individualising each player based of of ability 'Rating' and how the player compares 'Percentile', For the Match Day System 'Rating' is more significant due to being the first game. 'Percentile' Rating will have an impact after the 2nd Game. Once Player'Form' is considered.   
    def get_rating_boost(self): 
        if self.overall_rating >= 87:
            return 0.2
        elif self.overall_rating >= 84:
            return 0.25
        elif self.overall_rating >= 81:
            return 0.3
        elif self.overall_rating >= 78:
            return 0.35
        elif self.overall_rating >= 75:
            return 0.40
        else:
            return 0.45

    def is_forward(self): return self.position == "forward" #Positions Outfield
    def is_midfielder(self): return self.position == "midfielder"
    def is_defender(self): return self.position == "defender"

    def input_match_stats(self, minutes=0, goals=0, assists=0, #Type of Stats recorded for Outfield Players
                          yellow_card=False, red_card=False, clean_sheet=False, goals_conceded=0,
                          total_shots=0, shots_on_target=0, shots_off_target=0, tackles_loss=0,
                          total_passes=0, accurate_passes=0,
                          expected_goals=0, expected_assists=0,
                          big_chances_missed=0,
                          successful_dribbles=0, total_dribbles=0, conceded_penalty=0, missed_penalty=0,
                          accurate_crosses=0, total_crosses=0,
                          accurate_long_balls=0, total_long_balls=0,
                          dispossessed=0, tackles_won=0, interceptions=0,
                          clearances=0, ball_recoveries=0,
                          dribbled_past=0, duels_won=0, duels_lost=0,
                          ground_duels_won=0, ground_duels_total=0,
                          aerial_duels_won=0, aerial_duels_total=0, own_goal=0,
                          fouled=0, number_of_fouls=0):

        boost = self.get_rating_boost()

        # G/A boost
        self.adjust_rating(goals * 1)
        self.adjust_rating(assists * 1)
    
            

        if goals_conceded > 2:
            self.adjust_rating(-1)
            

        
        # Cards
        if yellow_card:
            self.adjust_rating(-1)
        if red_card:
            self.adjust_rating(-2)
                #Clean Sheet Bonus
        if clean_sheet:
            self.adjust_rating(boost)

        # Shot Accuracy
        if total_shots > 0:
            accuracy = shots_on_target / total_shots
            if accuracy >= 0.7:
                self.adjust_rating(boost)
            shots_off_target = total_shots - shots_on_target
            off_target_ratio = shots_off_target / total_shots
            if off_target_ratio >= 0.75:
                self.adjust_rating(-0.3)
            elif off_target_ratio >= 0.5:
                self.adjust_rating(-0.2)
            elif off_target_ratio >= 0.3:
                self.adjust_rating(-0.1)

        # xG comparison
        if goals > expected_goals:
            self.adjust_rating(boost)
        elif expected_goals > goals:
            self.adjust_rating(-0.2)

        # xA comparison
        if assists > expected_assists:
            self.adjust_rating(boost)
        elif expected_assists > assists:
            self.adjust_rating(-0.2)

        # Passing
        if total_passes > 0:
            pass_accuracy = accurate_passes / total_passes
            if pass_accuracy >= 0.9:
                self.adjust_rating(boost)
            elif pass_accuracy >= 0.75:
                self.adjust_rating(boost * 0.75)
            elif pass_accuracy >= 0.5:
                self.adjust_rating(boost * 0.5)
            else:
                self.adjust_rating(-0.3)

        # Dribbling Success Rate
        if total_dribbles > 0:
            dribble_rate = successful_dribbles / total_dribbles
            if dribble_rate >= 0.8:
                self.adjust_rating(boost)
            elif dribble_rate >= 0.5:
                self.adjust_rating(boost * 0.5)
            else:
                self.adjust_rating(-0.2)
            if tackles_won > tackles_loss:
                self.adjust_rating(boost)
            elif tackles_won < tackles_loss:
                self.adjust_rating(-boost)
             
        # Crossing
        if total_crosses > 0:
            crossing_rate = accurate_crosses / total_crosses
            if crossing_rate >= 0.5:
                self.adjust_rating(boost)
            elif crossing_rate >= 0.3:
                self.adjust_rating(boost * 0.5)

        # Long Balls
        if total_long_balls > 0:
            long_ball_rate = accurate_long_balls / total_long_balls
            if long_ball_rate >= 0.5:
                self.adjust_rating(boost)
            elif long_ball_rate >= 0.3:
                self.adjust_rating(boost * 0.5)

        # Possession Loss
        if dispossessed >= 3:
            self.adjust_rating(-0.1 * dispossessed)

        # Defensive Metrics
        if tackles_won >= 2:
            self.adjust_rating(tackles_won * 0.1)
        if interceptions >= 2:
            self.adjust_rating(interceptions * 0.1)
        if clearances >= 2:
            self.adjust_rating(clearances * 0.05)
        if ball_recoveries >= 5:
            self.adjust_rating(ball_recoveries * 0.05)
        if dribbled_past >= 2:
            self.adjust_rating(-0.1 * dribbled_past)

        # Duels
        total_duels = duels_won + duels_lost
        if total_duels > 0:
            duel_win_rate = duels_won / total_duels
            if duel_win_rate >= 0.6:
                self.adjust_rating(boost)
            elif duel_win_rate < 0.4:
                self.adjust_rating(-boost)

        if ground_duels_total > 0:
            ground_rate = ground_duels_won / ground_duels_total
            if ground_rate >= 0.6:
                self.adjust_rating(boost * 0.5)

        if aerial_duels_total > 0:
            aerial_rate = aerial_duels_won / aerial_duels_total
            if aerial_rate >= 0.6:
                self.adjust_rating(boost * 0.5)

        # Fouls and Being Fouled
        self.adjust_rating(fouled * 0.05)
        self.adjust_rating(-number_of_fouls * 0.1)

        # Played Full 90 Minutes
        if minutes >= 90:
            self.adjust_rating(0.2)

        # Big Chances Missed
        if big_chances_missed > 0:
            self.adjust_rating(-0.3 * big_chances_missed)

        if conceded_penalty > 0:
            self.adjust_rating(-2)
        if missed_penalty > 0:
            self.adjust_rating(-2)
        if minutes >= 90:
            self.adjust_rating(0.2) 
        if own_goal > 0:
            self.adjust_rating(-2)

class GoalkeeperProfile:
    def __init__(self, name, team, position, overall_rating):
        self.name = name
        self.team = team
        self.position = position.lower()
        self.overall_rating = overall_rating
        self.base_rating = 6
        self.match_rating = self.base_rating

    def adjust_rating(self, delta):
        self.match_rating = max(0, min(10, self.match_rating + delta))

    def get_rating_boost(self):
        if self.overall_rating >= 87:
            return 0.2
        elif self.overall_rating >= 84:
            return 0.25
        elif self.overall_rating >= 81:
            return 0.3
        elif self.overall_rating >= 78:
            return 0.35
        elif self.overall_rating >= 75:
            return 0.4
        else:
            return 0.5

    def input_match_stats(self,
                          saves=0,
                          goals_conceded=0,
                          xG_faced=0,
                          saves_inside_box=0,
                          saves_outside_box=0,
                          touches=0,
                          goals_prevented=0,
                          errors=0,
                          minutes_played=0,
                          penalty_saves=0,
                          total_passes=0,
                          accurate_passes=0,
                          total_long_balls=0,
                          accurate_long_balls=0,
                          yellow_card=False,
                          red_card=False,
                          clean_sheet=False):

        boost = self.get_rating_boost()

        # Saves
        self.adjust_rating(saves * 0.1)
        if saves_inside_box > 0:
            self.adjust_rating(saves_inside_box * 0.15)
        if saves_outside_box > 0:
            self.adjust_rating(saves_outside_box * 0.1)

        # Goals Conceded vs xG
        if goals_conceded < xG_faced:
            self.adjust_rating(boost)
        elif goals_conceded > xG_faced:
            self.adjust_rating(-boost)

                # Passing
        if total_passes > 0:
            pass_accuracy = accurate_passes / total_passes
            if pass_accuracy >= 0.9:
                self.adjust_rating(boost)
            elif pass_accuracy >= 0.75:
                self.adjust_rating(boost * 0.75)
            elif pass_accuracy >= 0.5:
                self.adjust_rating(boost * 0.5)
            else:
                self.adjust_rating(-0.3)

        # Goals prevented
        if goals_prevented > 0:
            self.adjust_rating(goals_prevented * 0.2)

        # Errors
        if errors == 0:
            self.adjust_rating(boost * 0.5)
        elif errors > 0:
            self.adjust_rating(-0.5 * errors)

        # Touches which can lead to distribution
        if touches >= 40:
            self.adjust_rating(boost * 0.5)
        elif touches >= 25:
            self.adjust_rating(boost * 0.2)

        # Penalty saves
        if penalty_saves > 0:
            self.adjust_rating(penalty_saves * 0.8)

        # Clean sheet 
        if clean_sheet and minutes_played >= 70:
            self.adjust_rating(0.5)

        # Played full match
        if minutes_played >= 90:
            self.adjust_rating(0.2)

        
        # Cards
        if yellow_card:
            self.adjust_rating(-1)
        if red_card:
            self.adjust_rating(-2)

# %%
#Mexico XI

# %%
gk = GoalkeeperProfile("Rangel", "Mexico", "goalkeeper", 74)
gk.input_match_stats(
    minutes_played=97,
    saves=2,
    saves_inside_box=1,
    saves_outside_box=1,
    goals_conceded=0,
    xG_faced=0.13,
    goals_prevented=0.13,
    total_passes=30,
    accurate_passes=26,
    total_long_balls=13,
    accurate_long_balls=9,
    touches=36,
    errors=0,
    penalty_saves=0,
    clean_sheet=True,
    yellow_card=False
)
print(f"{gk.name}'s match rating: {gk.match_rating:.2f}")
# Out:
# Rangel's match rating: 8.40

# %%
player = PlayerProfile("Gallardo", "Mexcio", "defender", 75)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=1,
    shots_on_target=0,
    accurate_passes=34,
    total_passes=45,
    expected_goals=0.04,
    expected_assists=0.05,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=2,
    total_long_balls=4,
    dispossessed=1,
    tackles_won=0,
    tackles_loss=0,
    clearances=3,
    interceptions=3,
    ball_recoveries=3,
    dribbled_past=0,
    duels_won=2,
    duels_lost=2,
    ground_duels_won=2,
    ground_duels_total=2,
    aerial_duels_won=0,
    aerial_duels_total=2,
    fouled=0,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=True, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Gallardo's match rating: 7.35

# %%
player = PlayerProfile("Vasquez", "Mexcio", "defender", 79)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=75,
    total_passes=81,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=4,
    dispossessed=0,
    tackles_won=1,
    tackles_loss=0,
    clearances=3,
    interceptions=1,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=4,
    duels_lost=2,
    ground_duels_won=1,
    ground_duels_total=1,
    aerial_duels_won=3,
    aerial_duels_total=5,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=True, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Vasquez's match rating: 7.95

# %%
player = PlayerProfile("Montes", "Mexcio", "defender", 75)

player.input_match_stats(
    minutes=90,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=60,
    total_passes=65,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=3,
    total_long_balls=6,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=3,
    interceptions=1,
    ball_recoveries=4,
    dribbled_past=0,
    duels_won=3,
    duels_lost=3,
    ground_duels_won=1,
    ground_duels_total=3,
    aerial_duels_won=2,
    aerial_duels_total=3,
    fouled=1,
    number_of_fouls=2,
    yellow_card=False,
    red_card=True,
    clean_sheet=True, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Montes's match rating: 5.60

# %%
player = PlayerProfile("Reyes", "Mexcio", "defender", 75)

player.input_match_stats(
    minutes=90,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=1,
    accurate_passes=38,
    total_passes=42,
    expected_goals=0.01,
    expected_assists=0.03,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=1,
    total_crosses=2,
    accurate_long_balls=5,
    total_long_balls=6,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=3,
    interceptions=1,
    ball_recoveries=2,
    dribbled_past=0,
    duels_won=1,
    duels_lost=0,
    ground_duels_won=0,
    ground_duels_total=0,
    aerial_duels_won=1,
    aerial_duels_total=1,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=True, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Reyes's match rating: 8.35

# %%
player = PlayerProfile("Lira", "Mexcio", "midfielder", 76)

player.input_match_stats(
    minutes=76,
    goals=0,
    assists=1,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=42,
    total_passes=45,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=4,
    total_long_balls=5,
    dispossessed=0,
    tackles_won=2,
    tackles_loss=0,
    clearances=1,
    interceptions=1,
    ball_recoveries=0,
    dribbled_past=0,
    duels_won=5,
    duels_lost=0,
    ground_duels_won=4,
    ground_duels_total=4,
    aerial_duels_won=1,
    aerial_duels_total=1,
    fouled=2,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Lira's match rating: 9.30

# %%
player = PlayerProfile("Fidalgo", "Mexcio", "midfielder", 75)

player.input_match_stats(
    minutes=66,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=30,
    total_passes=34,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=1,
    total_dribbles=1,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=5,
    dribbled_past=0,
    duels_won=3,
    duels_lost=0,
    ground_duels_won=3,
    ground_duels_total=3,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=2,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Fidalgo's match rating: 7.45

# %%
player = PlayerProfile("Gutierrez", "Mexcio", "midfielder", 77)

player.input_match_stats(
    minutes=66,
    goals=0,
    assists=0,
    total_shots=2,
    shots_on_target=0,
    accurate_passes=20,
    total_passes=23,
    expected_goals=0.19,
    expected_assists=0.17,
    successful_dribbles=0,
    total_dribbles=2,
    accurate_crosses=1,
    total_crosses=2,
    accurate_long_balls=1,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=2,
    duels_lost=5,
    ground_duels_won=1,
    ground_duels_total=5,
    aerial_duels_won=1,
    aerial_duels_total=2,
    fouled=1,
    number_of_fouls=2,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Gutierrez's match rating: 5.65

# %%
player = PlayerProfile("Quinones", "Mexcio", "forward", 81)

player.input_match_stats(
    minutes=79,
    goals=1,
    assists=0,
    total_shots=4,
    shots_on_target=2,
    accurate_passes=28,
    total_passes=33,
    expected_goals=0.37,
    expected_assists=0.08,
    successful_dribbles=5,
    total_dribbles=6,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=2,
    total_long_balls=2,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=4,
    dribbled_past=0,
    duels_won=7,
    duels_lost=3,
    ground_duels_won=7,
    ground_duels_total=9,
    aerial_duels_won=0,
    aerial_duels_total=1,
    fouled=2,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Quinones's match rating: 8.17

# %%
player = PlayerProfile("Alvarado", "Mexcio", "forward", 78)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=1,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=32,
    total_passes=35,
    expected_goals=0,
    expected_assists=0.71,
    successful_dribbles=2,
    total_dribbles=2,
    accurate_crosses=2,
    total_crosses=4,
    accurate_long_balls=2,
    total_long_balls=3,
    dispossessed=2,
    tackles_won=5,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=6,
    dribbled_past=1,
    duels_won=9,
    duels_lost=5,
    ground_duels_won=9,
    ground_duels_total=14,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=2,
    number_of_fouls=2,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Alvarado's match rating: 10.00

# %%
player = PlayerProfile("Jimenez", "Mexcio", "Position", 78)

player.input_match_stats(
    minutes=76,
    goals=1,
    assists=0,
    total_shots=3,
    shots_on_target=2,
    accurate_passes=15,
    total_passes=19,
    expected_goals=1.15,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=2,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=1,
    tackles_won=1,
    tackles_loss=0,
    clearances=1,
    interceptions=0,
    ball_recoveries=0,
    dribbled_past=0,
    duels_won=6,
    duels_lost=4,
    ground_duels_won=1,
    ground_duels_total=4,
    aerial_duels_won=5,
    aerial_duels_total=6,
    fouled=0,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Jimenez's match rating: 7.54

# %%
player = PlayerProfile("Mora", "Mexcio", "midfielder", 75)

player.input_match_stats(
    minutes=30,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=14,
    total_passes=14,
    expected_goals=0,
    expected_assists=0.09,
    successful_dribbles=1,
    total_dribbles=2,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=1,
    total_long_balls=1,
    dispossessed=2,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=1,
    ball_recoveries=2,
    dribbled_past=0,
    duels_won=1,
    duels_lost=4,
    ground_duels_won=1,
    ground_duels_total=5,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Mora's match rating: 6.30

# %%
player = PlayerProfile("Chavez", "Mexcio", "midfielder", 75)

player.input_match_stats(
    minutes=30,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=28,
    total_passes=28,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=1,
    total_long_balls=1,
    dispossessed=1,
    tackles_won=2,
    tackles_loss=0,
    clearances=1,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=2,
    duels_lost=2,
    ground_duels_won=2,
    ground_duels_total=4,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Chavez's match rating: 6.70

# %%
player = PlayerProfile("Alvarez", "Mexcio", "midfielder", 76)

player.input_match_stats(
    minutes=20,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=14,
    total_passes=15,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=1,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=1,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=0,
    duels_lost=0,
    ground_duels_won=2,
    ground_duels_total=2,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=1,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Alvarez's match rating: 6.85

# %%
player = PlayerProfile("Gonzalez", "Mexcio", "fowrard", 74)

player.input_match_stats(
    minutes=20,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=1,
    total_passes=1,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=0,
    dribbled_past=0,
    duels_won=0,
    duels_lost=1,
    ground_duels_won=0,
    ground_duels_total=1,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Gonzalez's match rating: 6.00

# %%
player = PlayerProfile("Vega", "Mexcio", "forward", 77)

player.input_match_stats(
    minutes=17,
    goals=0,
    assists=0.01,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=10,
    total_passes=10,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=1,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=0,
    duels_lost=1,
    ground_duels_won=0,
    ground_duels_total=1,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0 #Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Vega's match rating: 6.01

# %%
gk = GoalkeeperProfile("Williams", "South Africa", "goalkeeper", 66)
gk.input_match_stats(
    minutes_played=97,
    saves=2,
    saves_inside_box=2,
    saves_outside_box=0,
    goals_conceded=2,
    xG_faced=1.28,
    goals_prevented=-0.72,
    total_passes=40,
    accurate_passes=28,
    total_long_balls=19,
    accurate_long_balls=8,
    touches=55,
    errors=0,
    penalty_saves=0,
    clean_sheet=False,
    yellow_card=False
)
print(f"{gk.name}'s match rating: {gk.match_rating:.2f}")
# Out:
# Williams's match rating: 6.95

# %%
player = PlayerProfile("Modiba", "South Africa", "defender", 65)

player.input_match_stats(
    minutes=77,
    goals=0,
    assists=0,
    total_shots=1,
    shots_on_target=1,
    accurate_passes=12,
    total_passes=15,
    expected_goals=0.02,
    expected_assists=0.05,
    successful_dribbles=0,
    total_dribbles=2,
    accurate_crosses=0,
    total_crosses=2,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=0,
    tackles_won=3,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=4,
    dribbled_past=1,
    duels_won=5,
    duels_lost=6,
    ground_duels_won=5,
    ground_duels_total=10,
    aerial_duels_won=0,
    aerial_duels_total=1,
    fouled=2,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=2#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Modiba's match rating: 7.04

# %%
player = PlayerProfile("Mbokazi", "South Africa", "defender", 72)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=1,
    shots_on_target=1,
    accurate_passes=23,
    total_passes=30,
    expected_goals=0.01,
    expected_assists=0.05,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=1,
    total_crosses=2,
    accurate_long_balls=3,
    total_long_balls=8,
    dispossessed=3,
    tackles_won=2,
    tackles_loss=0,
    clearances=4,
    interceptions=1,
    ball_recoveries=3,
    dribbled_past=0,
    duels_won=5,
    duels_lost=5,
    ground_duels_won=5,
    ground_duels_total=9,
    aerial_duels_won=0,
    aerial_duels_total=1,
    fouled=3,
    number_of_fouls=1,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=2#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Mbokazi's match rating: 7.61

# %%
player = PlayerProfile("Okon", "South Africa", "defender", 66)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=45,
    total_passes=49,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=1,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=2,
    dispossessed=0,
    tackles_won=2,
    tackles_loss=0,
    clearances=6,
    interceptions=0,
    ball_recoveries=4,
    dribbled_past=0,
    duels_won=3,
    duels_lost=4,
    ground_duels_won=2,
    ground_duels_total=3,
    aerial_duels_won=1,
    aerial_duels_total=4,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=2#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Okon's match rating: 7.83

# %%
player = PlayerProfile("Sibisi", "South Africa", "defender", 64)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=41,
    total_passes=50,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=3,
    total_long_balls=8,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=1,
    interceptions=1,
    ball_recoveries=3,
    dribbled_past=0,
    duels_won=0,
    duels_lost=1,
    ground_duels_won=0,
    ground_duels_total=1,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=1,
    yellow_card=True,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=2#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Sibisi's match rating: 5.41

# %%
player = PlayerProfile("Mudau", "South Africa", "defender", 64)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=25,
    total_passes=29,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=0,
    total_long_balls=2,
    dispossessed=0,
    tackles_won=4,
    tackles_loss=0,
    clearances=2,
    interceptions=1,
    ball_recoveries=4,
    dribbled_past=1,
    duels_won=7,
    duels_lost=4,
    ground_duels_won=7,
    ground_duels_total=10,
    aerial_duels_won=0,
    aerial_duels_total=1,
    fouled=3,
    number_of_fouls=2,
    yellow_card=True,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=2#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Mudau's match rating: 6.66

# %%
player = PlayerProfile("Adams", "South Africa", "midfielder", 65)

player.input_match_stats(
    minutes=61,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=16,
    total_passes=20,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=1,
    total_dribbles=1,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=1,
    total_long_balls=2,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=1,
    duels_lost=1,
    ground_duels_won=1,
    ground_duels_total=1,
    aerial_duels_won=0,
    aerial_duels_total=1,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Adams's match rating: 7.46

# %%
player = PlayerProfile("Sithole", "South Africa", "midfielder", 66)

player.input_match_stats(
    minutes=49,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=17,
    total_passes=19,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=2,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=1,
    ball_recoveries=3,
    dribbled_past=2,
    duels_won=1,
    duels_lost=7,
    ground_duels_won=0,
    ground_duels_total=7,
    aerial_duels_won=1,
    aerial_duels_total=1,
    fouled=0,
    number_of_fouls=3,
    yellow_card=False,
    red_card=True,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Sithole's match rating: 3.61

# %%
player = PlayerProfile("Mokoena", "South Africa", "midfielder", 64)

player.input_match_stats(
    minutes=97,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=39,
    total_passes=42,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=2,
    accurate_long_balls=1,
    total_long_balls=2,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=1,
    interceptions=2,
    ball_recoveries=4,
    dribbled_past=2,
    duels_won=4,
    duels_lost=3,
    ground_duels_won=2,
    ground_duels_total=5,
    aerial_duels_won=2,
    aerial_duels_total=2,
    fouled=2,
    number_of_fouls=1,
    yellow_card=True,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Mokoena's match rating: 6.33

# %%
player = PlayerProfile("Rayners", "South Africa", "forward", 64)

player.input_match_stats(
    minutes=76,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=9,
    total_passes=10,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=1,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=1,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=1,
    duels_won=0,
    duels_lost=6,
    ground_duels_won=0,
    ground_duels_total=2,
    aerial_duels_won=0,
    aerial_duels_total=4,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Rayners's match rating: 6.00

# %%
player = PlayerProfile("Foster", "South Africa", "forward", 71)

player.input_match_stats(
    minutes=56,
    goals=0,
    assists=0,
    total_shots=1,
    shots_on_target=0,
    accurate_passes=1,
    total_passes=5,
    expected_goals=0.04,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=1,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=0,
    dribbled_past=1,
    duels_won=1,
    duels_lost=6,
    ground_duels_won=1,
    ground_duels_total=3,
    aerial_duels_won=0,
    aerial_duels_total=4,
    fouled=1,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Foster's match rating: 4.60

# %%
player = PlayerProfile("Mbatha", "South Africa", "midfielder", 62)

player.input_match_stats(
    minutes=40,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=4,
    total_passes=7,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=0,
    tackles_won=2,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=2,
    duels_lost=1,
    ground_duels_won=2,
    ground_duels_total=3,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Mbatha's match rating: 7.10

# %%
player = PlayerProfile("Zwane", "South Africa", "midfielder", 64)

player.input_match_stats(
    minutes=23,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=5,
    total_passes=7,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=0,
    dispossessed=1,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=2,
    dribbled_past=1,
    duels_won=0,
    duels_lost=3,
    ground_duels_won=0,
    ground_duels_total=3,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=1,
    yellow_card=False,
    red_card=True,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Zwane's match rating: 3.67

# %%
player = PlayerProfile("Makgopa", "South Africa", "forward", 62)

player.input_match_stats(
    minutes=20,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=2,
    total_passes=5,
    expected_goals=0,
    expected_assists=0.01,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=1,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=0,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=1,
    dribbled_past=0,
    duels_won=3,
    duels_lost=0,
    ground_duels_won=0,
    ground_duels_total=0,
    aerial_duels_won=3,
    aerial_duels_total=3,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Makgopa's match rating: 6.62

# %%
player = PlayerProfile("Appollis", "South Africa", "forward", 64)

player.input_match_stats(
    minutes=20,
    goals=0,
    assists=0,
    total_shots=0,
    shots_on_target=0,
    accurate_passes=5,
    total_passes=6,
    expected_goals=0,
    expected_assists=0,
    successful_dribbles=0,
    total_dribbles=0,
    accurate_crosses=0,
    total_crosses=0,
    accurate_long_balls=0,
    total_long_balls=1,
    dispossessed=0,
    tackles_won=1,
    tackles_loss=0,
    clearances=0,
    interceptions=0,
    ball_recoveries=0,
    dribbled_past=0,
    duels_won=1,
    duels_lost=0,
    ground_duels_won=1,
    ground_duels_total=1,
    aerial_duels_won=0,
    aerial_duels_total=0,
    fouled=0,
    number_of_fouls=0,
    yellow_card=False,
    red_card=False,
    clean_sheet=False, #Just for Defenders
    goals_conceded=0#Just for Defenders
               
)

print(f"{player.name}'s match rating: {player.match_rating:.2f}")
# Out:
# Appollis's match rating: 7.01
